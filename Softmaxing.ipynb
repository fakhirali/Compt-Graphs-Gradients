# %%
import TensionFlow as tf
import numpy as np
import importlib
importlib.reload(tf)
# Out:
# <module 'TensionFlow' from '/media/fakhir/SSD/Experiments/AutoGrad/TensionFlow/TensionFlow.py'>

# %%
l = tf.LinearLayer(10,1, bias=False)

# %%
inp = tf.Neuron(np.random.random(size=(5,10)))

# %%
out = inp @ l

# %%
mx = out.max(dim=0).broadcast(5)
y = out - mx 
exp = y.exp()
sum_exp = exp.sum(dim=0)
out_soft = exp / sum_exp.broadcast(5)

# %%
out_soft.make_graph()

# %%
out_soft.backward()

# %%
out, inp, l, out_soft
# Out:
# (<TensionFlow.Neuron at 0x7f096b8ed280>,
# ...
#  <TensionFlow.Neuron at 0x7f0990b92af0>)

# %%
out_soft.grad
# Out:
# array([[1.],
#        [1.],
#        [1.],
#        [1.],
#        [1.]])

# %%
out.grad
# Out:
# array([[ 1.84873753e-17],
#        [-9.10192101e-17],
#        [ 2.76764756e-17],
#        [ 2.16664001e-17],
#        [ 2.31889591e-17]])

# %%
a_s

# %%
a_s.make_graph()

# %%
ans.backward()

# %%
ans.grad
# Out:
# array([[1.],
#        [1.],
#        [1.],
#        [1.],
#        [1.]])

# %%
e.grad
# Out:
# array([[2.77555756e-17],
#        [2.77555756e-17],
#        [2.77555756e-17],
#        [2.77555756e-17],
#        [2.77555756e-17]])

# %%
e_s.grad
# Out:
# array([[-0.2417931]])

# %%
l.grad
