# %%
import TensionFlow as tf
import numpy as np
import importlib
importlib.reload(tf)
# Out:
# <module 'TensionFlow' from '/media/fakhir/SSD/AIExp/AutoGrad/TensionFlow/TensionFlow.py'>

# %%
l = tf.LinearLayer(10,1, bias=False)

# %%
inp = tf.Neuron(np.random.random(size=(5,10)))

# %%
out = inp @ l

# %%
m = out.max()

# %%
new_m = out - m.broadcast(5)

# %%
e = new_m.exp()

# %%
e_s = e.sum(0)

# %%
ans = e / e_s.broadcast(5)

# %%
a_s = ans.sum(0)

# %%
a_s

# %%
a_s.make_graph()

# %%
ans.grad
# Out:
# array([[1.],
#        [1.],
#        [1.],
#        [1.],
#        [1.]])

# %%
e.grad
# Out:
# array([[0.],
#        [0.],
#        [0.],
#        [0.],
#        [0.]])

# %%
e_s.grad
# Out:
# array([[-0.22922139]])

# %%
e_s
# Out:
# Tension: [[4.36259452]]
